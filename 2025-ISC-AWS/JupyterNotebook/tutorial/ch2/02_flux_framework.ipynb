# %% [markdown]
# <div>
# <center><img src="../assets/Flux-logo.svg" width="400"/>
# </div>
#
# # Chapter 2: Python Submission API 🐍️
#
# Flux also provides first-class python bindings which can be used to submit jobs programmatically.

# %% [markdown]
# ### Importing the flux package
#
# Flux requires python to build, so if you have Flux installed, you have at least one python installation that works. However, you can also `pip install flux-python` to get the `flux` package in a side-installation of python (which you may have to do in this notebook!)

# %%
# !python3 -c "import flux; print(flux.Flux())"
# Out:
# <flux.core.handle.Flux object at 0x155546ed0130>

# %%
import concurrent.futures
import os
import json
import flux
import flux.job
from flux.job import JobspecV1
from flux.job.JobID import JobID

# %% [markdown]
# ### `flux.job.JobspecV1` to create job specifications
#
# Flux represents work as a standard called the [Jobspec](https://flux-framework.readthedocs.io/projects/flux-rfc/en/latest/spec_25.html). While you could write YAML or JSON, it's much easier to use provided Python functions that take high level metadata (command, resources, etc) to generate them. We can then replicate our previous example of submitting multiple heterogeneous jobs using these Python helpers, and testing that Flux co-schedules them.

# %%
# connect to the running Flux instance
f = flux.Flux()

# Create the Jobspec from a command to run a python script, and specify resources
compute_jobreq = JobspecV1.from_command(
    command=["sleep", "0"], num_tasks=1, num_nodes=1, cores_per_task=1
    )
compute_jobreq.environment = {'TMPDIR': '/tmp/'}
id = flux.job.submit(f, compute_jobreq)

# When we submit, we get back the job identifier (JobID)
print(f'{id.f58 = }')
# Out:
# id.f58 = 'fAsfFYwuh'

# %% [markdown]
# We get a job ID, and the command will _block_ until a job ID is assigned. But, perhaps we want more information about the job, too.

# %%
# Maybe we want a bit more information about this job
info = flux.job.result(f, id)
print(f'{info.to_dict() = }')

# for i in range(100):
#     flux.job.submit(f, compute_jobreq) # submit and print out the jobid (in f58 format)
# Out:
# info.to_dict() = {'t_run': 1747934727.7275984, 't_cleanup': 1747934732.8789754, 'duration': 0.0, 'result': 'COMPLETED', 'waitstatus': 0, 'id': JobID(26095936077824), 't_submit': 1747934727.7054133, 'runtime': 5.151376962661743, 'returncode': 0, 'dependencies': [], 'annotations': {}, 'exception': {'occurred': False}}

# %% [markdown]
# Once we create the job, when we submit it in Python we get back a job identifier or jobid. We can then interact with the Flux handle, a connection to Flux, to get information about that job.
#
# ### `flux.job.get_job(handle, jobid)` to get job info

# %%
# Let's submit again to retrieve (and save) the job identifier
compute_jobreq = JobspecV1.from_command(
    command=["sleep", "15"], num_tasks=1, num_nodes=1, cores_per_task=1
    )
compute_jobreq.environment = {'TMPDIR': '/tmp/'}

## Explain how to set environment in Jobspec
# import os, json
# compute_jobreq.environment = dict(os.environ)

fluxjob = flux.job.submit(f, compute_jobreq)
fluxjobid = JobID(fluxjob.f58)
print(f"🎉️ Hooray, we just submitted {fluxjobid}!\n")

# Here is how to get your info. The first argument is the flux handle, then the jobid
jobinfo = flux.job.get_job(f, fluxjobid)
print(jobinfo)
# Out:
# 🎉️ Hooray, we just submitted fEj9nMUnK!
#
# {'t_depend': 1747934978.8019178, 't_run': 0.0, 't_cleanup': 0.0, 't_inactive': 0.0, 'duration': 0.0, 'expiration': 0.0, 'name': 'sleep', 'cwd': '', 'queue': '', 'project': '', 'bank': '', 'ntasks': 1, 'ncores': 1, 'nnodes': 1, 'priority': 16, 'ranks': '', 'nodelist': '', 'success': '', 'result': '', 'waitstatus': '', 'id': JobID(30308443357184), 't_submit': 1747934978.791045, 't_remaining': 0.0, 'state': 'SCHED', 'username': 'hobbs17', 'userid': 60943, 'urgency': 16, 'runtime': 0.0, 'status': 'SCHED', 'returncode': '', 'dependencies': [], 'annotations': {}, 'exception': {'occurred': '', 'severity': '', 'type': '', 'note': ''}}

# %% [markdown]
# Look at what came from `.get_job()`. It didn't block, but the job isn't complete yet -- that `t_run` is 0, which makes no sense, because the run time should be around 5 seconds. Notice the status is also 'SCHED', meaning that the job is being scheduled,

# %% [markdown]
# You can now run `flux jobs` to see the jobs that we submit from Python.

# %%
# !flux jobs -a --name="sleep"
# Out:
#        JOBID USER     NAME       ST NTASKS NNODES     TIME INFO
#    fC3FJfwtT hobbs17  sleep       R      1      1   5.548s tuolumne1024
#    fAsfFYwuh hobbs17  sleep      CD      1      1   0.138s tuolumne1024
#    fAky1B2Y7 hobbs17  sleep      CD      1      1   0.151s tuolumne1024
#    f9zoXKtcw hobbs17  sleep       F      1      1   0.040s tuolumne1024
#    f9epp5D1Z hobbs17  sleep       F      1      1   0.041s tuolumne1024
#    f9cud159Z hobbs17  sleep       F      1      1   0.046s tuolumne1024
#    f8qZEDKUj hobbs17  sleep       F      1      1   0.044s tuolumne1024
#    f8TYaVmcK hobbs17  sleep       F      1      1   0.041s tuolumne1024
#    f86WhWidm hobbs17  sleep      CA      1      1   13.83s tuolumne1024
#    f7ycr4RKd hobbs17  sleep       F      1      1   0.040s tuolumne1024
#    f7npt1f99 hobbs17  sleep       F      1      1   0.040s tuolumne1024
#    f7chBLMps hobbs17  sleep       F      1      1   0.045s tuolumne1024
#    f7LqVMtPy hobbs17  sleep       F      1      1   0.067s tuolumne1024

# %% [markdown]
# Under the hood, the `Jobspec` class is creating a YAML document that ultimately gets serialized as JSON and sent to Flux for ingestion, validation, queueing, scheduling, and eventually execution.  We can dump the raw JSON jobspec that is submitted, where we can see the exact resources requested and the task set to be executed on those resources.

# %%
print(compute_jobreq.dumps(indent=2))
# Out:
# {
#   "resources": [
#     {
#       "type": "node",
#       "count": 1,
#       "with": [
#         {
#           "type": "slot",
#           "count": 1,
#           "with": [
#             {
#               "type": "core",
#               "count": 1
#             }
#           ],
#           "label": "task"
#         }
#       ]
#     }
#   ],
#   "tasks": [
#     {
#       "command": [
#         "sleep",
#         "15"
#       ],
#       "slot": "task",
#       "count": {
#         "per_slot": 1
#       }
#     }
#   ],
#   "attributes": {
#     "system": {
#       "duration": 0,
#       "environment": {
#         "TMPDIR": "/tmp/"
#       }
#     }
#   },
#   "version": 1
# }

# %% [markdown]
# ### Playing with the Synchronous job submission API
#
# One slight hiccup to creating jobspecs in Python is that some attributes of a jobspec are set in the _initializer_ (`.from_command` or another method) while others are specified by methods to the jobspec itself. Below is an example, and here's a brief table for reference:
#
# | Operation                                      | CLI                                                                       | Python                                                                                     |
# |------------------------------------------------|---------------------------------------------------------------------------|--------------------------------------------------------------------------------------------|
# | Setting nodes, tasks, and cores                | -N _n_, -n _n_, and -c _n_, respectively                                  | in the initializer: num_nodes, num_tasks, num_cores                                        |
# | Setting node exclusivity                       | `-x` or enforced by policy                                                | in the initializer: exclusive=True                                                         |
# | Setting time limits                            | `-t MINUTES\|FSD`                                                         | `jobspec.duration=[seconds\|FSD]`                                                          |
# | Set working directory                          | Automatically set to current directory or `--cwd=`                        | `jobspec.cwd=[string of path]`                                                             |
# | Set environment                                | Default set to current environment, or `--env=[modifier]`                 | `jobspec.environment=[dict]`                                                               |
# | Setting stdout and stderr                      | `--output [OUT] --error [ERR]` or your terminal by default for alloc/run  | `flux jobs` / `flux job info *job_id*`                                                     |
# | Setting system attributes                      | `-S KEY[=VAL]`                                                            | `jobspec.setattr(key, val)`                                                                |
# | Set shell attributes                           | `-o KEY[=VAL]`                                                            | `jobspec.setattr_shell_option(key, val)`                                                   |
# | Modifying configuration of a subinstance       | `--conf` for batch/alloc                                                  | in the initializer, requires `.from_batch_command` or `.from_nest_command`                 |
#
# The example below is stolen from the [El Cap documentation maintained by Ramesh Pankajakshan](https://hpc.llnl.gov/documentation/user-guides/using-el-capitan-systems/introduction-and-quickstart/flux).
#
# _"Submitting jobs through Python is the civilized way of life" -Ramesh_

# %%
handle = flux.Flux()
jobspec = JobspecV1.from_command(
    command=["sleep", "5"], num_tasks=4, num_nodes=1,
)
jobspec.cwd = os.getcwd()
jobspec.exclusive=1
jobspec.duration="5m"
jobspec.environment = {"TMPDIR": "/tmp/"}
jobspec.stdout="PYEXAMPLE.{{id}}.out"
jobspec.stderr="PYEXAMPLE.{{id}}.err"
id = flux.job.submit(handle, jobspec)

info = flux.job.event_wait(handle, id, "finish")
## fetch the R, give you a nodelist
print(info)
# Out:
# 1747934732.87898: finish {'status': 0}

# %% [markdown]
# ### `FluxExecutor` for bulk submission
#
# We can use the FluxExecutor class to submit large numbers of jobs to Flux. This method resembles python's `concurrent.futures` interface.

# %%
from flux.job import FluxExecutor
with FluxExecutor() as executor:
    compute_jobspec = JobspecV1.from_command(["sleep", "3"])
    compute_jobspec.environment = {"TMPDIR": "/tmp/"}
    futures = [executor.submit(compute_jobspec) for _ in range(10)]
    # wait for the jobid for each job, as a proxy for the job being submitted
# all jobs submitted - print timings
print("I'm all done")
# Out:
# I'm all done

# %%
# Submit the FluxExecutor based script.
# flux python bulksubmit_executor.py -n200 /bin/sleep 0

# %%
jobspec = flux.job.JobspecV1.from_command(["/bin/true"])
jobspec.environment = {"TMPDIR": "/tmp/"}
with flux.job.FluxExecutor() as executor:
        futs = [executor.submit(jobspec) for _ in range(5)]
        for f in concurrent.futures.as_completed(futs):
                print(f.result())
# Out:
# 0
# 0
# 0
# 0
# 0

# %% [markdown]
# ### `flux.event_watch` to watch events
#
# If you want to get the output of a job (or more generally, stream events) you can do that as follows. Let's submit a quick job, and then look at the output.

# %%
# Create the Jobspec from a command to run a python script, and specify resources
f = flux.Flux()
jobspec = flux.job.JobspecV1.from_command(
    command=["echo", "The Tales of Beedle the Bard"], num_tasks=1, num_nodes=1, cores_per_task=1)
jobspec.environment = {"TMPDIR": "/tmp/"}
jobid = flux.job.submit(f, jobspec, waitable=True)

# Wait until the job finishes
flux.job.wait(f, jobid)
print(jobid)

# Wait on an event to complete and then print its associated data
for line in flux.job.event_watch(f, jobid, "guest.output"):
    print(line)
# Out:
# fDtB89axw
# 1747934867.70586: header {'version': 1, 'encoding': {'stdout': 'UTF-8', 'stderr': 'UTF-8'}, 'count': {'stdout': 1, 'stderr': 1}, 'options': {}}
# 1747934867.81982: data {'stream': 'stdout', 'rank': '0', 'data': 'The Tales of Beedle the Bard\n'}
# 1747934867.81990: data {'stream': 'stderr', 'rank': '0', 'eof': True}
# 1747934867.81991: data {'stream': 'stdout', 'rank': '0', 'eof': True}

# %% [markdown]
# ### `flux.job.JobOutputWatch` to synchronously watch for job output with asynchronous job submission

# %%
# Create the Jobspec from a command to run a python script, and specify resources
f = flux.Flux()
jobspec = JobspecV1.from_command(
    command=["echo", "The Tales of Beedle the Bard"], num_tasks=4, num_nodes=1
)
jobspec.environment = {"TMPDIR": "/tmp/"}
jobid = flux.job.submit(f, jobspec)

t = flux.job.output.JobOutputWatchLines(f, jobid).getline()
print(t)
# Out:
# ['stdout', 'The Tales of Beedle the Bard']

# %% [markdown]
# ### `flux.job.JobOutputWatch` to watch for job output with asynchronous job submission

# %%
import concurrent.futures
import flux.job

## Define something we want to happen when the futures are fulfilled
def print_output(fut):
    t = flux.job.output.JobOutputWatchLines(f, fut.jobid()).getline()
    for line in t:
        print(f'{fut.jobid()}: {line}')

## Submit all of the futures using the executor.
jobspec = flux.job.JobspecV1.from_command(["echo", "Wingardium Leviosa!"])
jobspec.environment = {"TMPDIR": "/tmp/"}

with flux.job.FluxExecutor() as executor:
        futs = [executor.submit(jobspec) for _ in range(5)]
        for fut in futs:
            fut.add_done_callback(print_output)
# Out:
# fE4zRHhoM: stdout
# fE4zRHhoM: Wingardium Leviosa!
# fE4zSmh5h: stdout
# fE4zSmh5h: Wingardium Leviosa!
# fE4zSmh5i: stdout
# fE4zSmh5i: Wingardium Leviosa!
# fE4zSmh5j: stdout
# fE4zSmh5j: Wingardium Leviosa!
# fE4zSmh5k: stdout
# fE4zSmh5k: Wingardium Leviosa!

# %% [markdown]
# ### `flux.job.job_list` to list jobs
#
# Finally, it can be really helpful to get an entire listing of jobs. You can do that as follows. Note that the `job_list` is creating a remote procedure call (rpc) and we call `get` to retrieve the output.

# %%
flux.job.job_list(f).get()
# Out:
# {'jobs': [{'id': 324704392970240,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878454.2070212,
#    't_depend': 1747878454.2199697,
#    't_run': 1747878454.2341714,
#    't_cleanup': 1747878469.3649247,
#    't_inactive': 1747878469.369873,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core0'}},
#    'waitstatus': 0},
#   {'id': 324870806175744,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878464.1258276,
#    't_depend': 1747878464.141535,
#    't_run': 1747878464.1594179,
#    't_cleanup': 1747878464.350665,
#    't_inactive': 1747878464.3524082,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core0'}},
#    'waitstatus': 0},
#   {'id': 324870789398528,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878464.1255689,
#    't_depend': 1747878464.141449,
#    't_run': 1747878464.1588166,
#    't_cleanup': 1747878464.346974,
#    't_inactive': 1747878464.3487926,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core0'}},
#    'waitstatus': 0},
#   {'id': 324870806175745,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878464.125853,
#    't_depend': 1747878464.1416163,
#    't_run': 1747878464.1595619,
#    't_cleanup': 1747878464.3448787,
#    't_inactive': 1747878464.3468306,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core0'}},
#    'waitstatus': 0},
#   {'id': 324870806175747,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878464.125966,
#    't_depend': 1747878464.1417947,
#    't_run': 1747878464.1598005,
#    't_cleanup': 1747878464.3318758,
#    't_inactive': 1747878464.3338895,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core1'}},
#    'waitstatus': 0},
#   {'id': 324870806175746,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878464.1258707,
#    't_depend': 1747878464.1416953,
#    't_run': 1747878464.159677,
#    't_cleanup': 1747878464.3286908,
#    't_inactive': 1747878464.330779,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core1'}},
#    'waitstatus': 0},
#   {'id': 324866024669184,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878463.841284,
#    't_depend': 1747878463.8554122,
#    't_run': 1747878463.8694134,
#    't_cleanup': 1747878464.019977,
#    't_inactive': 1747878464.0222154,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core[0-3]'}},
#    'waitstatus': 0},
#   {'id': 324863357091840,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878463.6826913,
#    't_depend': 1747878463.6964183,
#    't_run': 1747878463.7091215,
#    't_cleanup': 1747878463.8293562,
#    't_inactive': 1747878463.83109,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core0'}},
#    'waitstatus': 0},
#   {'id': 324860555296768,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878463.514815,
#    't_depend': 1747878463.5302455,
#    't_run': 1747878463.5446348,
#    't_cleanup': 1747878463.6694407,
#    't_inactive': 1747878463.6712325,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core0'}},
#    'waitstatus': 0},
#   {'id': 324853492088833,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878463.0944877,
#    't_depend': 1747878463.1146033,
#    't_run': 1747878463.140186,
#    't_cleanup': 1747878463.3309584,
#    't_inactive': 1747878463.33263,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core0'}},
#    'waitstatus': 0},
#   {'id': 324853492088834,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878463.094521,
#    't_depend': 1747878463.1147048,
#    't_run': 1747878463.1404014,
#    't_cleanup': 1747878463.327411,
#    't_inactive': 1747878463.3291886,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core0'}},
#    'waitstatus': 0},
#   {'id': 324853492088832,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878463.093852,
#    't_depend': 1747878463.1144931,
#    't_run': 1747878463.1392252,
#    't_cleanup': 1747878463.3245955,
#    't_inactive': 1747878463.326336,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core0'}},
#    'waitstatus': 0},
#   {'id': 324853508866049,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878463.094911,
#    't_depend': 1747878463.1149285,
#    't_run': 1747878463.1407058,
#    't_cleanup': 1747878463.304309,
#    't_inactive': 1747878463.3061838,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core1'}},
#    'waitstatus': 0},
#   {'id': 324853508866048,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878463.0948374,
#    't_depend': 1747878463.1148322,
#    't_run': 1747878463.140552,
#    't_cleanup': 1747878463.2979014,
#    't_inactive': 1747878463.2997508,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core1'}},
#    'waitstatus': 0},
#   {'id': 324791131176980,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.377209,
#    't_depend': 1747878459.4293532,
#    't_run': 1747878462.1058612,
#    't_cleanup': 1747878462.6632924,
#    't_inactive': 1747878462.665441,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core4'}},
#    'waitstatus': 0},
#   {'id': 324791131176971,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3769891,
#    't_depend': 1747878459.4289744,
#    't_run': 1747878462.0805142,
#    't_cleanup': 1747878462.6561086,
#    't_inactive': 1747878462.6581895,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core4'}},
#    'waitstatus': 0},
#   {'id': 324791131176983,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3772728,
#    't_depend': 1747878459.4294806,
#    't_run': 1747878462.106042,
#    't_cleanup': 1747878462.6454892,
#    't_inactive': 1747878462.6474571,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core6'}},
#    'waitstatus': 0},
#   {'id': 324791131176981,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3772292,
#    't_depend': 1747878459.4293954,
#    't_run': 1747878462.105918,
#    't_cleanup': 1747878462.6432068,
#    't_inactive': 1747878462.6451492,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core4'}},
#    'waitstatus': 0},
#   {'id': 324791131176982,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3772497,
#    't_depend': 1747878459.4294393,
#    't_run': 1747878462.1059813,
#    't_cleanup': 1747878462.6304119,
#    't_inactive': 1747878462.6324625,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core6'}},
#    'waitstatus': 0},
#   {'id': 324791131176976,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3771079,
#    't_depend': 1747878459.4291854,
#    't_run': 1747878462.0898142,
#    't_cleanup': 1747878462.627579,
#    't_inactive': 1747878462.6294432,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core6'}},
#    'waitstatus': 0},
#   {'id': 324791131176985,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3773012,
#    't_depend': 1747878459.4295628,
#    't_run': 1747878462.2013805,
#    't_cleanup': 1747878462.6254468,
#    't_inactive': 1747878462.6275113,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core5'}},
#    'waitstatus': 0},
#   {'id': 324791131176973,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3770344,
#    't_depend': 1747878459.4290574,
#    't_run': 1747878462.0807786,
#    't_cleanup': 1747878462.6204224,
#    't_inactive': 1747878462.6231835,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core7'}},
#    'waitstatus': 0},
#   {'id': 324791131176978,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3771536,
#    't_depend': 1747878459.4292696,
#    't_run': 1747878462.1045725,
#    't_cleanup': 1747878462.6143117,
#    't_inactive': 1747878462.6172323,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core8'}},
#    'waitstatus': 0},
#   {'id': 324791131176979,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3771791,
#    't_depend': 1747878459.4293118,
#    't_run': 1747878462.1057942,
#    't_cleanup': 1747878462.6052003,
#    't_inactive': 1747878462.610679,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core0'}},
#    'waitstatus': 0},
#   {'id': 324791131176963,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3768287,
#    't_depend': 1747878459.4285843,
#    't_run': 1747878462.0055232,
#    't_cleanup': 1747878462.6035025,
#    't_inactive': 1747878462.6073234,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core6'}},
#    'waitstatus': 0},
#   {'id': 324791131176965,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3768623,
#    't_depend': 1747878459.428668,
#    't_run': 1747878462.005763,
#    't_cleanup': 1747878462.5988083,
#    't_inactive': 1747878462.604538,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core7'}},
#    'waitstatus': 0},
#   {'id': 324791131176967,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3768992,
#    't_depend': 1747878459.4287963,
#    't_run': 1747878462.0541272,
#    't_cleanup': 1747878462.5952632,
#    't_inactive': 1747878462.6030936,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core5'}},
#    'waitstatus': 0},
#   {'id': 324791131176975,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3770802,
#    't_depend': 1747878459.4291432,
#    't_run': 1747878462.0809264,
#    't_cleanup': 1747878462.5901146,
#    't_inactive': 1747878462.5965514,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core9'}},
#    'waitstatus': 0},
#   {'id': 324791131176984,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3772888,
#    't_depend': 1747878459.4295216,
#    't_run': 1747878462.1775382,
#    't_cleanup': 1747878462.5885475,
#    't_inactive': 1747878462.5964034,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core7'}},
#    'waitstatus': 0},
#   {'id': 324791131176968,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376916,
#    't_depend': 1747878459.4288428,
#    't_run': 1747878462.0550466,
#    't_cleanup': 1747878462.5854013,
#    't_inactive': 1747878462.5951986,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core3'}},
#    'waitstatus': 0},
#   {'id': 324791131176970,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3769598,
#    't_depend': 1747878459.4289327,
#    't_run': 1747878462.0554652,
#    't_cleanup': 1747878462.5577188,
#    't_inactive': 1747878462.5787065,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core8'}},
#    'waitstatus': 0},
#   {'id': 324791131176966,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3768814,
#    't_depend': 1747878459.428711,
#    't_run': 1747878462.0168707,
#    't_cleanup': 1747878462.5575743,
#    't_inactive': 1747878462.5743558,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core2'}},
#    'waitstatus': 0},
#   {'id': 324791131176977,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3771303,
#    't_depend': 1747878459.4292276,
#    't_run': 1747878462.1044793,
#    't_cleanup': 1747878462.549145,
#    't_inactive': 1747878462.5691652,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core3'}},
#    'waitstatus': 0},
#   {'id': 324791131176969,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.37694,
#    't_depend': 1747878459.4288883,
#    't_run': 1747878462.055208,
#    't_cleanup': 1747878462.538614,
#    't_inactive': 1747878462.5501826,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core9'}},
#    'waitstatus': 0},
#   {'id': 324791131176972,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.377012,
#    't_depend': 1747878459.4290156,
#    't_run': 1747878462.0806751,
#    't_cleanup': 1747878462.5372026,
#    't_inactive': 1747878462.5499675,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core1'}},
#    'waitstatus': 0},
#   {'id': 324791131176974,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3770597,
#    't_depend': 1747878459.4291015,
#    't_run': 1747878462.080851,
#    't_cleanup': 1747878462.531976,
#    't_inactive': 1747878462.5468335,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core0'}},
#    'waitstatus': 0},
#   {'id': 324791131176962,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3768065,
#    't_depend': 1747878459.4285426,
#    't_run': 1747878461.990902,
#    't_cleanup': 1747878462.5178819,
#    't_inactive': 1747878462.5449173,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core2'}},
#    'waitstatus': 0},
#   {'id': 324791114399791,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3767111,
#    't_depend': 1747878459.4283721,
#    't_run': 1747878461.9331448,
#    't_cleanup': 1747878462.5172892,
#    't_inactive': 1747878462.543313,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core2'}},
#    'waitstatus': 0},
#   {'id': 324791114399788,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3766549,
#    't_depend': 1747878459.4282434,
#    't_run': 1747878461.898533,
#    't_cleanup': 1747878462.5172107,
#    't_inactive': 1747878462.5389214,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core5'}},
#    'waitstatus': 0},
#   {'id': 324791131176961,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376788,
#    't_depend': 1747878459.4285007,
#    't_run': 1747878461.9736497,
#    't_cleanup': 1747878462.5038378,
#    't_inactive': 1747878462.5313163,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core1'}},
#    'waitstatus': 0},
#   {'id': 324791114399785,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3766,
#    't_depend': 1747878459.4281096,
#    't_run': 1747878461.8535755,
#    't_cleanup': 1747878462.4529827,
#    't_inactive': 1747878462.5037866,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core2'}},
#    'waitstatus': 0},
#   {'id': 324791131176960,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376768,
#    't_depend': 1747878459.428456,
#    't_run': 1747878461.9490504,
#    't_cleanup': 1747878462.4529264,
#    't_inactive': 1747878462.5036004,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core8'}},
#    'waitstatus': 0},
#   {'id': 324791114399792,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3767276,
#    't_depend': 1747878459.428414,
#    't_run': 1747878461.9334016,
#    't_cleanup': 1747878462.4459562,
#    't_inactive': 1747878462.4935715,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core0'}},
#    'waitstatus': 0},
#   {'id': 324791114399790,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3766925,
#    't_depend': 1747878459.4283297,
#    't_run': 1747878461.932712,
#    't_cleanup': 1747878462.430097,
#    't_inactive': 1747878462.4776642,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core1'}},
#    'waitstatus': 0},
#   {'id': 324791114399784,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3765814,
#    't_depend': 1747878459.4280684,
#    't_run': 1747878461.8160596,
#    't_cleanup': 1747878462.4282975,
#    't_inactive': 1747878462.4775681,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core3'}},
#    'waitstatus': 0},
#   {'id': 324791131176964,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3768456,
#    't_depend': 1747878459.4286263,
#    't_run': 1747878462.005662,
#    't_cleanup': 1747878462.4252174,
#    't_inactive': 1747878462.477471,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core3'}},
#    'waitstatus': 0},
#   {'id': 324791114399789,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3766747,
#    't_depend': 1747878459.4282863,
#    't_run': 1747878461.931065,
#    't_cleanup': 1747878462.4209943,
#    't_inactive': 1747878462.4745996,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core4'}},
#    'waitstatus': 0},
#   {'id': 324791114399787,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3766363,
#    't_depend': 1747878459.4282005,
#    't_run': 1747878461.898443,
#    't_cleanup': 1747878462.3704028,
#    't_inactive': 1747878462.3851311,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core7'}},
#    'waitstatus': 0},
#   {'id': 324791114399786,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3766167,
#    't_depend': 1747878459.4281569,
#    't_run': 1747878461.856891,
#    't_cleanup': 1747878462.2830913,
#    't_inactive': 1747878462.2924047,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core1'}},
#    'waitstatus': 0},
#   {'id': 324791114399778,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3764644,
#    't_depend': 1747878459.4217267,
#    't_run': 1747878461.5284266,
#    't_cleanup': 1747878462.2260633,
#    't_inactive': 1747878462.2456565,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core9'}},
#    'waitstatus': 0},
#   {'id': 324791114399783,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3765624,
#    't_depend': 1747878459.428026,
#    't_run': 1747878461.770361,
#    't_cleanup': 1747878462.22602,
#    't_inactive': 1747878462.2439106,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core8'}},
#    'waitstatus': 0},
#   {'id': 324791114399782,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376542,
#    't_depend': 1747878459.4279745,
#    't_run': 1747878461.7341592,
#    't_cleanup': 1747878462.1978428,
#    't_inactive': 1747878462.2370033,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core9'}},
#    'waitstatus': 0},
#   {'id': 324791114399781,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3765225,
#    't_depend': 1747878459.427932,
#    't_run': 1747878461.7280967,
#    't_cleanup': 1747878462.1977704,
#    't_inactive': 1747878462.236816,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core5'}},
#    'waitstatus': 0},
#   {'id': 324791114399777,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3764431,
#    't_depend': 1747878459.4216824,
#    't_run': 1747878461.5059307,
#    't_cleanup': 1747878462.1235745,
#    't_inactive': 1747878462.1779962,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core5'}},
#    'waitstatus': 0},
#   {'id': 324791114399780,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3765037,
#    't_depend': 1747878459.4278889,
#    't_run': 1747878461.6709163,
#    't_cleanup': 1747878462.1000872,
#    't_inactive': 1747878462.1451404,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core7'}},
#    'waitstatus': 0},
#   {'id': 324791114399774,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376384,
#    't_depend': 1747878459.4215567,
#    't_run': 1747878461.5022092,
#    't_cleanup': 1747878462.0472522,
#    't_inactive': 1747878462.0905035,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core6'}},
#    'waitstatus': 0},
#   {'id': 324791114399779,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3764849,
#    't_depend': 1747878459.4278395,
#    't_run': 1747878461.5285337,
#    't_cleanup': 1747878462.0528421,
#    't_inactive': 1747878462.0904179,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core6'}},
#    'waitstatus': 0},
#   {'id': 324791114399775,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376404,
#    't_depend': 1747878459.4215982,
#    't_run': 1747878461.502373,
#    't_cleanup': 1747878462.0469882,
#    't_inactive': 1747878462.0903184,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core4'}},
#    'waitstatus': 0},
#   {'id': 324791114399766,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3762276,
#    't_depend': 1747878459.4212232,
#    't_run': 1747878461.3632822,
#    't_cleanup': 1747878462.0468857,
#    't_inactive': 1747878462.0902362,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core4'}},
#    'waitstatus': 0},
#   {'id': 324791114399756,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.37602,
#    't_depend': 1747878459.4208007,
#    't_run': 1747878461.3135104,
#    't_cleanup': 1747878462.0468361,
#    't_inactive': 1747878462.0901568,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core0'}},
#    'waitstatus': 0},
#   {'id': 324791114399759,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376086,
#    't_depend': 1747878459.4209282,
#    't_run': 1747878461.313755,
#    't_cleanup': 1747878462.0220826,
#    't_inactive': 1747878462.0900736,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core8'}},
#    'waitstatus': 0},
#   {'id': 324791114399771,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376327,
#    't_depend': 1747878459.4214327,
#    't_run': 1747878461.4088378,
#    't_cleanup': 1747878462.0169728,
#    't_inactive': 1747878462.0899632,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core3'}},
#    'waitstatus': 0},
#   {'id': 324791114399762,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3761463,
#    't_depend': 1747878459.4210546,
#    't_run': 1747878461.362934,
#    't_cleanup': 1747878462.0056074,
#    't_inactive': 1747878462.075019,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core6'}},
#    'waitstatus': 0},
#   {'id': 324791114399772,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3763463,
#    't_depend': 1747878459.4214742,
#    't_run': 1747878461.4089515,
#    't_cleanup': 1747878461.9868999,
#    't_inactive': 1747878462.0475078,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core9'}},
#    'waitstatus': 0},
#   {'id': 324791114399770,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3763094,
#    't_depend': 1747878459.4213886,
#    't_run': 1747878461.406816,
#    't_cleanup': 1747878461.986806,
#    't_inactive': 1747878462.0474222,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core0'}},
#    'waitstatus': 0},
#   {'id': 324791114399764,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376184,
#    't_depend': 1747878459.421141,
#    't_run': 1747878461.3631265,
#    't_cleanup': 1747878461.9834063,
#    't_inactive': 1747878462.0473332,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core7'}},
#    'waitstatus': 0},
#   {'id': 324791114399761,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3761253,
#    't_depend': 1747878459.4210114,
#    't_run': 1747878461.320029,
#    't_cleanup': 1747878461.9834437,
#    't_inactive': 1747878462.047199,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core1'}},
#    'waitstatus': 0},
#   {'id': 324791114399769,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3762896,
#    't_depend': 1747878459.4213471,
#    't_run': 1747878461.4066577,
#    't_cleanup': 1747878461.9837499,
#    't_inactive': 1747878462.0470757,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core4'}},
#    'waitstatus': 0},
#   {'id': 324791114399758,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376067,
#    't_depend': 1747878459.4208853,
#    't_run': 1747878461.3136659,
#    't_cleanup': 1747878461.9837046,
#    't_inactive': 1747878462.021372,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core8'}},
#    'waitstatus': 0},
#   {'id': 324791114399768,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3762715,
#    't_depend': 1747878459.4213054,
#    't_run': 1747878461.3634675,
#    't_cleanup': 1747878461.9557855,
#    't_inactive': 1747878462.0209494,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core9'}},
#    'waitstatus': 0},
#   {'id': 324791114399757,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3760426,
#    't_depend': 1747878459.4208431,
#    't_run': 1747878461.313588,
#    't_cleanup': 1747878461.9557307,
#    't_inactive': 1747878462.0208583,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core3'}},
#    'waitstatus': 0},
#   {'id': 324791114399763,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3761654,
#    't_depend': 1747878459.421099,
#    't_run': 1747878461.363044,
#    't_cleanup': 1747878461.955673,
#    't_inactive': 1747878462.0207055,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core5'}},
#    'waitstatus': 0},
#   {'id': 324791114399776,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3764215,
#    't_depend': 1747878459.421641,
#    't_run': 1747878461.5024788,
#    't_cleanup': 1747878461.9489279,
#    't_inactive': 1747878461.9935553,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core2'}},
#    'waitstatus': 0},
#   {'id': 324791114399767,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3762505,
#    't_depend': 1747878459.4212635,
#    't_run': 1747878461.3633835,
#    't_cleanup': 1747878461.9201756,
#    't_inactive': 1747878461.9869766,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core7'}},
#    'waitstatus': 0},
#   {'id': 324791114399773,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3763652,
#    't_depend': 1747878459.4215152,
#    't_run': 1747878461.4694474,
#    't_cleanup': 1747878461.918573,
#    't_inactive': 1747878461.983641,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank0/core3'}},
#    'waitstatus': 0},
#   {'id': 324791114399760,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.376104,
#    't_depend': 1747878459.4209697,
#    't_run': 1747878461.3199332,
#    't_cleanup': 1747878461.91433,
#    't_inactive': 1747878461.983524,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core6'}},
#    'waitstatus': 0},
#   {'id': 324791114399754,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3759766,
#    't_depend': 1747878459.4206812,
#    't_run': 1747878461.311631,
#    't_cleanup': 1747878461.889766,
#    't_inactive': 1747878461.9492784,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core2'}},
#    'waitstatus': 0},
#   {'id': 324791114399755,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3759968,
#    't_depend': 1747878459.4207265,
#    't_run': 1747878461.3133783,
#    't_cleanup': 1747878461.8877056,
#    't_inactive': 1747878461.949173,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank1/core1'}},
#    'waitstatus': 0},
#   {'id': 324791114399751,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.375919,
#    't_depend': 1747878459.420555,
#    't_run': 1747878461.2573388,
#    't_cleanup': 1747878461.837721,
#    't_inactive': 1747878461.914529,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core8'}},
#    'waitstatus': 0},
#   {'id': 324791114399750,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3758993,
#    't_depend': 1747878459.4205108,
#    't_run': 1747878461.2532876,
#    't_cleanup': 1747878461.8338757,
#    't_inactive': 1747878461.9132617,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core0'}},
#    'waitstatus': 0},
#   {'id': 324791114399753,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3759575,
#    't_depend': 1747878459.4206393,
#    't_run': 1747878461.3023853,
#    't_cleanup': 1747878461.8352423,
#    't_inactive': 1747878461.9129772,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank2/core2'}},
#    'waitstatus': 0},
#   {'id': 324791114399749,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747878459.3758788,
#    't_depend': 1747878459.4204686,
#    't_run': 1747878461.244596,
#    't_cleanup': 1747878461.8348253,
#    't_inactive': 1747878461.8982894,
#    'state': 64,
#    'name': 'sleep',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 0.0,
#    'annotations': {'sched': {'resource_summary': 'rank3/core1'}},
#    'waitstatus': 0},
#   {'id': 324791114399752,
#    'userid': 1000,
# ...
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 129015213981698,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866765.4055948,
#    't_depend': 1747866765.4197905,
#    't_run': 1747866765.4385486,
#    't_cleanup': 1747866765.5677385,
#    't_inactive': 1747866765.5698724,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 129015213981696,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866765.4053397,
#    't_depend': 1747866765.4196727,
#    't_run': 1747866765.4371684,
#    't_cleanup': 1747866765.5666842,
#    't_inactive': 1747866765.5685706,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 129015213981697,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866765.4053702,
#    't_depend': 1747866765.4197373,
#    't_run': 1747866765.4377825,
#    't_cleanup': 1747866765.5657594,
#    't_inactive': 1747866765.567563,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 128542515920899,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866737.2306073,
#    't_depend': 1747866737.247398,
#    't_run': 1747866737.2642074,
#    't_cleanup': 1747866737.3984272,
#    't_inactive': 1747866737.400446,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 128542532698112,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866737.2307894,
#    't_depend': 1747866737.2474604,
#    't_run': 1747866737.2646296,
#    't_cleanup': 1747866737.398374,
#    't_inactive': 1747866737.4000564,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 128542515920898,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866737.2304292,
#    't_depend': 1747866737.2473383,
#    't_run': 1747866737.26415,
#    't_cleanup': 1747866737.3898923,
#    't_inactive': 1747866737.3918068,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 128542515920897,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866737.230221,
#    't_depend': 1747866737.2472837,
#    't_run': 1747866737.2640746,
#    't_cleanup': 1747866737.386026,
#    't_inactive': 1747866737.3884838,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 128542515920896,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866737.2301898,
#    't_depend': 1747866737.2472239,
#    't_run': 1747866737.2634478,
#    't_cleanup': 1747866737.3830864,
#    't_inactive': 1747866737.386576,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127922866225153,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866700.2961879,
#    't_depend': 1747866700.3125887,
#    't_run': 1747866700.3337932,
#    't_cleanup': 1747866700.4716632,
#    't_inactive': 1747866700.4745963,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127922849447937,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866700.2957435,
#    't_depend': 1747866700.312455,
#    't_run': 1747866700.332887,
#    't_cleanup': 1747866700.4716392,
#    't_inactive': 1747866700.4745202,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127922849447936,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866700.2953684,
#    't_depend': 1747866700.3122082,
#    't_run': 1747866700.3321836,
#    't_cleanup': 1747866700.4716012,
#    't_inactive': 1747866700.474432,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127922866225152,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866700.2959692,
#    't_depend': 1747866700.3125277,
#    't_run': 1747866700.3336875,
#    't_cleanup': 1747866700.4714413,
#    't_inactive': 1747866700.4743311,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127922866225154,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866700.296374,
#    't_depend': 1747866700.312644,
#    't_run': 1747866700.3338618,
#    't_cleanup': 1747866700.4713767,
#    't_inactive': 1747866700.4736876,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127841060519937,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866695.4200263,
#    't_depend': 1747866695.4357548,
#    't_run': 1747866695.4523873,
#    't_cleanup': 1747866695.5876558,
#    't_inactive': 1747866695.5900896,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127841060519936,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866695.4198685,
#    't_depend': 1747866695.4357061,
#    't_run': 1747866695.4523323,
#    't_cleanup': 1747866695.5860164,
#    't_inactive': 1747866695.5878496,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127841043742722,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866695.4196348,
#    't_depend': 1747866695.435646,
#    't_run': 1747866695.4522634,
#    't_cleanup': 1747866695.5788617,
#    't_inactive': 1747866695.5813556,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127841043742721,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866695.419357,
#    't_depend': 1747866695.435591,
#    't_run': 1747866695.4515913,
#    't_cleanup': 1747866695.5776029,
#    't_inactive': 1747866695.5802417,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127841043742720,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866695.4191809,
#    't_depend': 1747866695.4355354,
#    't_run': 1747866695.4508944,
#    't_cleanup': 1747866695.5774999,
#    't_inactive': 1747866695.5798023,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127448960204801,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866672.0488052,
#    't_depend': 1747866672.0616822,
#    't_run': 1747866672.0770037,
#    't_cleanup': 1747866672.2097425,
#    't_inactive': 1747866672.2117765,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127448960204802,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866672.048974,
#    't_depend': 1747866672.0617325,
#    't_run': 1747866672.0770824,
#    't_cleanup': 1747866672.2097058,
#    't_inactive': 1747866672.2114594,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127448960204804,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866672.0493279,
#    't_depend': 1747866672.061832,
#    't_run': 1747866672.0778656,
#    't_cleanup': 1747866672.2065227,
#    't_inactive': 1747866672.2087288,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127448960204803,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866672.0491757,
#    't_depend': 1747866672.0617812,
#    't_run': 1747866672.0777931,
#    't_cleanup': 1747866672.2064602,
#    't_inactive': 1747866672.2084303,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 127448960204800,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747866672.0486372,
#    't_depend': 1747866672.0616238,
#    't_run': 1747866672.0763075,
#    't_cleanup': 1747866672.2055638,
#    't_inactive': 1747866672.2073593,
#    'state': 64,
#    'name': 'true',
#    'ntasks': 1,
#    'ncores': 1,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 115819749048320,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747865978.8914003,
#    't_depend': 1747865978.9047582,
#    't_run': 1747865978.9188552,
#    't_cleanup': 1747865979.0529318,
#    't_inactive': 1747865979.0546005,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 109881017237504,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747865624.9141693,
#    't_depend': 1747865624.9273136,
#    't_run': 1747865624.9413505,
#    't_cleanup': 1747865625.07883,
#    't_inactive': 1747865625.0805721,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 72360300380160,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747861421.4279685,
#    't_depend': 1747861421.4396155,
#    't_run': 1747861421.4539661,
#    't_cleanup': 1747861421.594565,
#    't_inactive': 1747861421.5964954,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 72211318702080,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747861412.547656,
#    't_depend': 1747861412.5594087,
#    't_run': 1747861412.572885,
#    't_cleanup': 1747861412.7184875,
#    't_inactive': 1747861412.7203724,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '0',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 71971404513280,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747861398.2480702,
#    't_depend': 1747861398.2598777,
#    't_run': 1747861398.2749739,
#    't_cleanup': 1747861398.4307406,
#    't_inactive': 1747861398.4325054,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '1',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 71897081446400,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747861393.8176818,
#    't_depend': 1747861393.830515,
#    't_run': 1747861393.8439155,
#    't_cleanup': 1747861393.9873743,
#    't_inactive': 1747861393.9892077,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '2',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0},
#   {'id': 66872389140480,
#    'userid': 1000,
#    'urgency': 16,
#    'priority': 16,
#    't_submit': 1747861094.3215373,
#    't_depend': 1747861094.3382685,
#    't_run': 1747861094.3821988,
#    't_cleanup': 1747861094.5478764,
#    't_inactive': 1747861094.5508585,
#    'state': 64,
#    'name': 'echo',
#    'ntasks': 4,
#    'ncores': 4,
#    'duration': 0.0,
#    'nnodes': 1,
#    'ranks': '3',
#    'nodelist': 'a100cf62dc4f',
#    'success': True,
#    'exception_occurred': False,
#    'result': 1,
#    'expiration': 9223372036.0,
#    'waitstatus': 0}]}
